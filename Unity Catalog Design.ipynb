# %% [markdown]
# ### Unity Catalog Design
# name -> apextrust_catalog

# %%
# %sql 

-- Frist we list the exist catlogs here 
ShOW CATALOGS;

# %%
# %sql

CREATE CATALOG apextrust_catalog;

COMMENT ON CATALOG apextrust_catalog IS'we don t have extrnal location';

# %%
# %sql
-- Here we checks the currrent catalog is use 

 SELECT current_catalog();

# %%
# %sql 
-- we need to select your catalog apextrust_catalog for use or I mean creating the schema 

USE CATALOG apextrust_catalog;
     
     SELECT current_catalog();

# %%
# %sql 
-- For our undtanding and information we do the describe catalog 

DESCRIBE CATALOG EXTENDED apextrust_catalog;

# %% [markdown]
# #### Create Schemas
#  1. Bronze
#  2. Silver
#  3. Gold

# %%
# %sql
-- Here we create all  schemas under the catalog apextrust_catalog 

CREATE SCHEMA IF NOT EXISTS Bronz;

CREATE SCHEMA IF NOT EXISTS Silver;

CREATE SCHEMA IF NOT EXISTS Gold;

# %%
# %sql 
-- list the schemas we created 
SHOW SCHEMAS;

# %%
# %sql

CREATE SCHEMA IF NOT EXISTS landing;

# %%
# %sql 
USE SCHEMA landing;
     
CREATE VOLUME If NOT EXISTS apextrust_catalog.landing.operational_data;

# %% [markdown]
# Note
# Catalog = organization
# Schema = data layer or domain
